# %%
import numpy as np
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import Adam

# %%
np.random.seed(0)
points = 500
X = np.linspace(-3,3,points)
y = np.sin(X) + np.random.uniform(-0.5,0.5,points)

plt.scatter(X,y)

# %%
model =  Sequential()
model.add(Dense(50,activation='sigmoid', input_dim = 1 ))
model.add(Dense(30,activation='sigmoid'))
model.add(Dense(1))
# Out:
# 2022-08-26 05:02:16.961226: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-08-26 05:02:16.961446: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-08-26 05:02:16.961483: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcublas.so.11'; dlerror: libcublas.so.11: cannot open shared object file: No such file or directory
# 2022-08-26 05:02:16.961517: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcublasLt.so.11'; dlerror: libcublasLt.so.11: cannot open shared object file: No such file or directory
# 2022-08-26 05:02:16.961549: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcufft.so.10'; dlerror: libcufft.so.10: cannot open shared object file: No such file or directory
# 2022-08-26 05:02:16.961582: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcurand.so.10'; dlerror: libcurand.so.10: cannot open shared object file: No such file or directory
# 2022-08-26 05:02:16.961614: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcusolver.so.11'; dlerror: libcusolver.so.11: cannot open shared object file: No such file or directory
# 2022-08-26 05:02:16.961646: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcusparse.so.11'; dlerror: libcusparse.so.11: cannot open shared object file: No such file or directory
# 2022-08-26 05:02:16.961678: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudnn.so.8'; dlerror: libcudnn.so.8: cannot open shared object file: No such file or directory
# 2022-08-26 05:02:16.961684: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1850] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2022-08-26 05:02:16.962121: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
adam = Adam(lr = 0.01)
model.compile(loss='mse',optimizer=adam)
model.fit(X,y,epochs=50)
# Out:
# /home/sametaydin/.local/lib/python3.10/site-packages/keras/optimizers/optimizer_v2/adam.py:110: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# Epoch 1/50
# 16/16 [==============================] - 1s 3ms/step - loss: 0.5534
# Epoch 2/50
# 16/16 [==============================] - 0s 3ms/step - loss: 0.2831
# Epoch 3/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.2592
# Epoch 4/50
# 16/16 [==============================] - 0s 3ms/step - loss: 0.2370
# Epoch 5/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.2205
# Epoch 6/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.2226
# Epoch 7/50
# 16/16 [==============================] - 0s 3ms/step - loss: 0.2303
# Epoch 8/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.2089
# Epoch 9/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1978
# Epoch 10/50
# 16/16 [==============================] - 0s 3ms/step - loss: 0.1910
# Epoch 11/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1846
# Epoch 12/50
# 16/16 [==============================] - 0s 3ms/step - loss: 0.1756
# Epoch 13/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1632
# Epoch 14/50
# 16/16 [==============================] - 0s 3ms/step - loss: 0.1580
# Epoch 15/50
# 16/16 [==============================] - 0s 3ms/step - loss: 0.1547
# Epoch 16/50
# 16/16 [==============================] - 0s 3ms/step - loss: 0.1410
# Epoch 17/50
# 16/16 [==============================] - 0s 3ms/step - loss: 0.1389
# Epoch 18/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1329
# Epoch 19/50
# 16/16 [==============================] - 0s 2ms/step - loss: 0.1233
# Epoch 20/50
# 16/16 [==============================] - 0s 3ms/step - loss: 0.1194
# Epoch 21/50
# 16/16 [==============================] - 0s 3ms/step - loss: 0.1182
# Epoch 22/50
# 16/16 [==============================] - 0s 3ms/step - loss: 0.1162
# Epoch 23/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1174
# Epoch 24/50
# 16/16 [==============================] - 0s 3ms/step - loss: 0.1137
# Epoch 25/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1172
# Epoch 26/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1136
# Epoch 27/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1100
# Epoch 28/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1184
# Epoch 29/50
# 16/16 [==============================] - 0s 3ms/step - loss: 0.1104
# Epoch 30/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1136
# Epoch 31/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1138
# Epoch 32/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1082
# Epoch 33/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1098
# Epoch 34/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1133
# Epoch 35/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1062
# Epoch 36/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1122
# Epoch 37/50
# 16/16 [==============================] - 0s 3ms/step - loss: 0.1158
# Epoch 38/50
# 16/16 [==============================] - 0s 3ms/step - loss: 0.1248
# Epoch 39/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1106
# Epoch 40/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1060
# Epoch 41/50
# 16/16 [==============================] - 0s 5ms/step - loss: 0.1049
# Epoch 42/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1025
# Epoch 43/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1108
# Epoch 44/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1076
# Epoch 45/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1050
# Epoch 46/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1006
# Epoch 47/50
# 16/16 [==============================] - 0s 4ms/step - loss: 0.1066
# Epoch 48/50
# 16/16 [==============================] - 0s 3ms/step - loss: 0.1071
# Epoch 49/50
# 16/16 [==============================] - 0s 3ms/step - loss: 0.1008
# Epoch 50/50
# 16/16 [==============================] - 0s 3ms/step - loss: 0.1047

# %%
predictions = model.predict(X)
plt.scatter(X,y)
plt.plot(X,predictions,'ro')
# Out:
# 16/16 [==============================] - 0s 1ms/step
